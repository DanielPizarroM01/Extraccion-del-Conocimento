# %%
#Tituo: Laboratorio 2
#Fecha: 22 de Mayo
# Autor: Daniel Edaurdo Pizarro Macuixtle

# %%
import pandas as pd

# %%
#Conjunto de datos base para la generación del Big Data
datos = {
    "usuario": ["ana","pepe", "luis","rosita","carolina","paco"],
    "edad": [14,22,35,40,62,70],
    "ciudad": ["cuitlahuac","yanga","atoyac","paraje","fortin","cuichapa"],
    "compras_realizadas": [5,10,1,2,15,3],
    "activo": [True,True,True,False,True,False],
    "fecha_registro": ["2026-01-10","2026-05-21","2026-02-10","2026-03-11","2026-04-15","2026-07-25"]
}

# %%
dfDatos =  pd.DataFrame(datos)

# %%
dfDatos
# Out:
#     usuario  edad      ciudad  compras_realizadas  activo fecha_registro
# 0       ana    14  cuitlahuac                   5    True     2026-01-10
# 1      pepe    22       yanga                  10    True     2026-05-21
# 2      luis    35      atoyac                   1    True     2026-02-10
# 3    rosita    40      paraje                   2   False     2026-03-11
# 4  carolina    62      fortin                  15    True     2026-04-15
# 5      paco    70    cuichapa                   3   False     2026-07-25

# %%
cantidad= 1000000

# %% [raw]
# import random

# %%
# Crear el dataFrame de 1000000 de registros
dfMillon = pd.DataFrame({
    "nombre": [random.choice(dfDatos["usuario"]) for _ in range(cantidad)],
    "edad": [random.randint(18,80) for _ in range(cantidad)],
    "ciudad": [random.choice(dfDatos["ciudad"]) for _ in range(cantidad)],
    "compras_realizadas": [random.randint(1,10) for _ in range(cantidad)],
    "activo": [random.choice(dfDatos["activo"]) for _ in range(cantidad)],
    "fecha_registro": [random.choice(dfDatos["fecha_registro"]) for _ in range(cantidad)]
})

# %%
dfMillon.shape
# Out:
# (1000000, 6)

# %%
dfMillon.dtypes
# Out:
# nombre                  str
# edad                  int64
# ciudad                  str
# compras_realizadas    int64
# activo                 bool
# fecha_registro          str
# dtype: object

# %%
dfMillon.memory_usage(deep= True)
# Out:
# Index                      132
# nombre                61832107
# edad                   8000000
# ciudad                63834524
# compras_realizadas     8000000
# activo                 1000000
# fecha_registro        67000000
# dtype: int64

# %%
datos_instagram = {
    "influencer": ["@cancun_vibes", "@travel_mexico", "@beach_lover", "@paradise_found", "@azul_turquesa", "@explora_qroo"],
    "ciudad_tema": ["cancun", "playa_del_carmen", "tulum", "isla_mujeres", "cozumel", "bacalar"],
    "tipo_post": ["photo", "video", "reel", "carousel"],
    "fecha_registro": ["2026-01-15", "2026-02-20", "2026-03-12", "2026-04-05", "2026-05-22"]
}

# %%
datos_instagram = {
    "influencer": ["@cancun_vibes", "@travel_mexico", "@beach_lover", "@paradise_found", "@azul_turquesa", "@explora_qroo"],
    "ciudad_tema": ["cancun", "playa_del_carmen", "tulum", "isla_mujeres", "cozumel", "bacalar"],
    "tipo_post": ["photo", "video", "reel", "carousel", "photo", "video"], # Agregados 2 para llegar a 6
    "fecha_registro": ["2026-01-15", "2026-02-20", "2026-03-12", "2026-04-05", "2026-05-22", "2026-05-22"] # Agregado 1 para llegar a 6
}

dfBase = pd.DataFrame(datos_instagram)
dfBase
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 8
#       1 datos_instagram = {
#       2     "influencer": ["@cancun_vibes", "@travel_mexico", "@beach_lover", "@paradise_found", "@azul_turquesa", "@explora_qroo"],
#       3     "ciudad_tema": ["cancun", "playa_del_carmen", "tulum", "isla_mujeres", "cozumel", "bacalar"],
#       4     "tipo_post": ["photo", "video", "reel", "carousel", "photo", "video"], # Agregados 2 para llegar a 6
#       5     "fecha_registro": ["2026-01-15", "2026-02-20", "2026-03-12", "2026-04-05", "2026-05-22", "2026-05-22"] # Agregado 1 para llegar a 6
#       6 }
# ----> 8 dfBase = pd.DataFrame(datos_instagram)
#       9 dfBase
#
# NameError: name 'pd' is not defined
